# %%
# Create a large text dataset (5500+ words)
text = """
Data science is an interdisciplinary field that focuses on extracting meaningful insights from structured and unstructured information. Machine learning enables systems to learn patterns automatically without being explicitly programmed for every scenario. Artificial intelligence is transforming industries by improving decision-making processes and automating repetitive tasks. Natural language processing allows computers to understand, interpret, and generate human language effectively.
Python has become one of the most popular programming languages for data analysis and machine learning applications. It provides powerful libraries that simplify complex computations and enable rapid development. Data visualization helps analysts communicate insights clearly through charts, graphs, and dashboards. Statistical methods are essential for validating models and ensuring accurate predictions.
Big data technologies are designed to handle massive volumes of information generated from various sources. Cloud computing provides scalable infrastructure for storing and processing large datasets efficiently. Data cleaning is a crucial step that ensures the quality and reliability of the dataset before analysis begins. Feature engineering improves model performance by selecting and transforming relevant variables.
Deep learning models use neural networks with multiple layers to capture complex patterns in data. Computer vision allows machines to interpret visual information from images and videos. Reinforcement learning trains agents to make decisions by rewarding desired behaviors. Time series analysis is useful for forecasting trends based on historical data patterns.
Databases store structured information and allow efficient retrieval using queries. Structured query language is commonly used to interact with relational database systems. Data warehouses integrate data from multiple sources for analytical purposes. Data lakes store raw information in its native format for future processing.
Exploratory data analysis helps in understanding patterns, detecting anomalies, and forming hypotheses. Supervised learning uses labeled data to train predictive models. Unsupervised learning discovers hidden patterns in unlabeled datasets. Clustering algorithms group similar data points based on their characteristics.
Classification models predict categorical outcomes, while regression models estimate continuous values. Evaluation metrics such as accuracy, precision, and recall are used to measure model performance. Cross-validation helps ensure that the model generalizes well to unseen data. Overfitting occurs when a model learns noise instead of meaningful patterns.
Dimensionality reduction techniques simplify datasets while preserving important information. Principal component analysis is widely used for reducing feature space. Data transformation techniques normalize and scale values for better model performance. Pipelines automate preprocessing and model training workflows.
Ethics in artificial intelligence is important to ensure fairness, transparency, and accountability. Bias in data can lead to unfair predictions and outcomes. Data privacy is a major concern in modern digital systems. Security measures protect sensitive information from unauthorized access.
Business intelligence tools help organizations make data-driven decisions. Predictive analytics forecasts future outcomes based on historical trends. Descriptive analytics summarizes past data to understand performance. Prescriptive analytics suggests actions to optimize results.
Internet of things devices generate continuous streams of real-time data. Edge computing processes data closer to the source to reduce latency. Blockchain technology ensures secure and transparent transactions. Cybersecurity protects systems from digital threats and attacks.
Software development involves designing, coding, testing, and maintaining applications. Agile methodology promotes iterative development and continuous improvement. Version control systems track changes in code and enable collaboration. Debugging is the process of identifying and fixing errors in programs.
User experience design focuses on creating intuitive and engaging interfaces. Human computer interaction studies how people interact with digital systems. Accessibility ensures that applications are usable by individuals with diverse abilities. Responsive design adapts interfaces to different screen sizes and devices.
Education technology enhances learning through digital platforms and interactive tools. Online courses provide flexibility and accessibility for students worldwide. Virtual classrooms enable remote learning experiences. Gamification increases engagement by incorporating game elements into education.
Healthcare analytics improves patient outcomes through data-driven insights. Medical imaging technologies assist in diagnosing diseases accurately. Wearable devices monitor health metrics in real time. Telemedicine enables remote consultation and treatment.
Financial technology is transforming banking and payment systems. Digital transactions are becoming more secure and convenient. Fraud detection systems identify suspicious activities using machine learning. Risk management helps organizations minimize potential losses.
Supply chain management ensures efficient movement of goods and services. Logistics optimization reduces costs and improves delivery times. Inventory management tracks stock levels and demand patterns. Automation enhances productivity in manufacturing processes.
Environmental data analysis helps monitor climate change and sustainability efforts. Renewable energy sources reduce dependence on fossil fuels. Smart cities use technology to improve urban living conditions. Geographic information systems analyze spatial data effectively.
"""# Repeat to exceed 5500 word

print("Total words:", len(text.split()))
# Out:
# Total words: 733

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# Lowercase
text = text.lower()

# Tokenization
tokens = word_tokenize(text)

# Remove punctuation
tokens = [word for word in tokens if word not in string.punctuation]

# Remove stopwords
stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word not in stop_words]

print("Sample tokens:", tokens[:20])
# Out:
# Sample tokens: ['data', 'science', 'interdisciplinary', 'field', 'focuses', 'extracting', 'meaningful', 'insights', 'structured', 'unstructured', 'information', 'machine', 'learning', 'enables', 'systems', 'learn', 'patterns', 'automatically', 'without', 'explicitly']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Word2Vec expects list of sentences
# We'll create small chunks as sentences

sentences = []
sentence_length = 10

for i in range(0, len(tokens), sentence_length):
    sentences.append(tokens[i:i+sentence_length])

print("Sample sentence:", sentences[0])
# Out:
# Sample sentence: ['data', 'science', 'interdisciplinary', 'field', 'focuses', 'extracting', 'meaningful', 'insights', 'structured', 'unstructured']

# %%
# !pip install gensim
from gensim.models import Word2Vec

# CBOW Model (sg=0)
cbow_model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    sg=0
)

# Skip-Gram Model (sg=1)
skipgram_model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    sg=1
)

# %%
print("CBOW Vocabulary Size:", len(cbow_model.wv))
print("Skip-Gram Vocabulary Size:", len(skipgram_model.wv))
# Out:
# CBOW Vocabulary Size: 406
# Skip-Gram Vocabulary Size: 406

# %%
words = ["data", "science", "machine", "learning", "python"]

for word in words:
    print(f"\nWord: {word}")
    print("CBOW Vector:", cbow_model.wv[word][:10])  # first 10 values
    print("Skip-Gram Vector:", skipgram_model.wv[word][:10])
# Out:
# Word: data
# CBOW Vector: [-0.00063325  0.00032214  0.00510293  0.00902293 -0.0093007  -0.00731939
#   0.0065592   0.00922795 -0.00511579 -0.00379316]
# Skip-Gram Vector: [-0.00078988  0.00039648  0.00511861  0.00906511 -0.00910045 -0.00776647
#   0.00681873  0.01012568 -0.00535641 -0.00392617]
#
# Word: science
# CBOW Vector: [-0.00439641  0.00759085  0.0090559  -0.00898732  0.00946699 -0.00984848
#  -0.0063955   0.00786862 -0.00030689  0.00134389]
# Skip-Gram Vector: [-0.00443855  0.0076472   0.00902683 -0.00898478  0.00955162 -0.00990475
#  -0.00635803  0.00793659 -0.00031313  0.00129646]
#
# Word: machine
# CBOW Vector: [-0.00223327 -0.00968181  0.00925473  0.00205908 -0.00113219 -0.00555591
#  -0.00846021 -0.00979836  0.00892011 -0.00254625]
# Skip-Gram Vector: [-0.00232052 -0.00955337  0.00931368  0.00199112 -0.00115376 -0.00580123
#  -0.00846779 -0.0094629   0.00891785 -0.00242936]
#
# Word: learning
# CBOW Vector: [ 5.0295770e-05  3.1390875e-03 -6.8172002e-03 -1.3369451e-03
# ...

# %%
target_word = "data"

print("\nCBOW Similar Words:")
print(cbow_model.wv.most_similar(target_word, topn=5))

print("\nSkip-Gram Similar Words:")
print(skipgram_model.wv.most_similar(target_word, topn=5))
# Out:
# CBOW Similar Words:
# [('python', 0.3608841896057129), ('provides', 0.2938789129257202), ('engaging', 0.2764023542404175), ('blockchain', 0.27359461784362793), ('renewable', 0.2319250851869583)]
#
# Skip-Gram Similar Words:
# [('python', 0.3645458519458771), ('provides', 0.3079279661178589), ('engaging', 0.27971115708351135), ('blockchain', 0.27446967363357544), ('renewable', 0.24185197055339813)]
